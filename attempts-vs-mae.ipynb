# %%
import pandas as pd
from ggplot import *
import matplotlib as mpl

# %%
mpl.rcParams["figure.figsize"] = "10, 5"

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(1500)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792399075893)>

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(750)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792399029513)>

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(325)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792398984653)>
