# %%
import pandas as pd
from ggplot import *
import matplotlib as mpl

# %%
mpl.rcParams["figure.figsize"] = "10, 5"
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv')) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8752593564009)>
