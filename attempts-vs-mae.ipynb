# %%
import pandas as pd
from ggplot import *
import matplotlib as mpl

# %%
mpl.rcParams["figure.figsize"] = "10, 5"

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(1000)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792401609333)>

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(500)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792401422301)>

# %%
ggplot(aes(x='mae', y='attempts'), data=pd.read_csv('allstate.csv').head(250)) \
    + geom_point() + theme_xkcd()
# Out:
# <ggplot: (8792401573161)>
